# %%
import pandas as pd
import matplotlib.pyplot as plt
counts = pd.read_csv("../data/condition_counts.csv")

# %%
counts.iloc[:,17:19].head()
# Out:
#        thrB      thrC
# 0  0.446067  0.585381
# 1  0.252470  0.424583
# 2  0.572800  0.756352
# 3 -0.597959 -0.502712
# 4 -0.725097 -0.716888

# %%
plt.plot(counts.iloc[:,19])
plt.show()

# %%
plt.plot(counts.iloc[:,20])
plt.show()

# %%
counts.iloc[:,16:17]
# Out:
#         thrA
# 0   0.433363
# 1   0.286869
# 2   0.665324
# 3  -0.624009
# 4  -0.705003
# 5  -0.648753
# 6  -0.767622
# 7  -0.886077
# 8  -0.348482
# 9  -0.596795
# 10 -0.870640
# 11  0.092476
# 12 -0.187415
# 13 -0.072493
# 14 -0.623206
# 15  0.086637
# 16 -0.099949
# 17 -0.157299
# 18  0.020923
# 19 -0.123893
# 20 -0.635545
# 21 -0.788032
# 22 -0.723857
# 23 -0.822522
# 24 -0.879898
# 25 -0.153764
# 26 -0.793433
# 27 -0.277701
# 28 -0.841253
# 29 -0.839470
# 30  0.000000
# 31  0.165663
# 32  0.200112
# 33  0.066907
# 34 -0.364345
# 35  0.154578
# 36 -0.814791
# 37 -0.181361
# 38 -0.091286
# 39 -0.138329
# 40 -0.834582
# 41  0.598088
# 42  0.930141
# 43  0.697677
# 44 -0.788658
